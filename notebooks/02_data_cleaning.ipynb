# %% [markdown]
# # 1. Import Libraries
#
# Import the required libraries that will be used throughout this notebook for the data cleaning process.

# %%
import pandas as pd

# %% [markdown]
# # 2. Load Dataset
#
# Load the raw dataset that will be cleaned and prepared for analysis in this notebook.

# %%
df = pd.read_excel("../data/raw/Sample - Superstore.xls")

# %% [markdown]
# # 3. Initial Dataset Shape
#
# Review the dataset dimensions before cleaning to establish a baseline for comparison after the cleaning process is complete.

# %%
df.shape

# %% [markdown]
# # 4. Check Missing Values
#
# Identify columns containing missing values to determine whether any data requires cleaning before analysis.

# %%
df.isnull().sum().sort_values(ascending=False)
